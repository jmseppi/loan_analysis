# %%
import pandas as pd
import numpy as np
from fancyimpute import SoftImpute
import seaborn as sns
import pandas_profiling
import matplotlib.gridspec as gs
import matplotlib.pyplot as plt
import itertools

# %matplotlib inline

# %% [markdown]
# # Part 1: Data Exploration and Evaluation

# %%
# select columns to load for csv
load_cols = ['loan_amnt', 'funded_amnt', 'term', 'int_rate', 'grade', 'annual_inc', 'issue_d', 'dti', 'revol_bal', 'total_pymnt', 'loan_status']
df_loans = pd.read_csv('data/loan.csv', usecols = load_cols)
df_loans.shape
# Out:
# (887379, 11)

# %%
df_loans.dtypes
# Out:
# loan_amnt      float64
# funded_amnt    float64
# term            object
# int_rate       float64
# grade           object
# annual_inc     float64
# issue_d         object
# loan_status     object
# dti            float64
# revol_bal      float64
# total_pymnt    float64
# dtype: object

# %%
df_loans.head()
# Out:
#    loan_amnt  funded_amnt        term  int_rate grade  annual_inc   issue_d  \
# 0     5000.0       5000.0   36 months     10.65     B     24000.0  Dec-2011
# 1     2500.0       2500.0   60 months     15.27     C     30000.0  Dec-2011
# 2     2400.0       2400.0   36 months     15.96     C     12252.0  Dec-2011
# 3    10000.0      10000.0   36 months     13.49     C     49200.0  Dec-2011
# 4     3000.0       3000.0   60 months     12.69     B     80000.0  Dec-2011
#
#    loan_status    dti  revol_bal   total_pymnt
# 0   Fully Paid  27.65    13648.0   5861.071414
# 1  Charged Off   1.00     1687.0   1008.710000
# 2   Fully Paid   8.72     2956.0   3003.653644
# 3   Fully Paid  20.00     5598.0  12226.302212
# 4      Current  17.94    27783.0   3242.170000

# %%
# check for infinity in any numeric columns
np.isinf(df_loans.select_dtypes(include=[np.number]).values).sum(axis  = 0)
# Out:
# array([0, 0, 0, 0, 0, 0, 0])

# %% [markdown]
# ## Missing Data
# Only column 'annual_inc' has missing values. None of the numeric columns have infinity.
# I used softImpute to Impute the missing data. (for the documentation - "Matrix completion by iterative soft thresholding of SVD decompositions.") I have had good experiences with this imputation method in the past. softImpute minimizes the mean absolute error.
#
# ## Outliers
# For this analysis, although there are outliers in the data, I did not remove, or adjust them. I would like to spend more time with the data before deciding what an outlier for this dataset.

# %%
# check for missing values
pd.isnull(df_loans).sum(axis = 0)
# Out:
# loan_amnt      0
# funded_amnt    0
# term           0
# int_rate       0
# grade          0
# annual_inc     4
# issue_d        0
# loan_status    0
# dti            0
# revol_bal      0
# total_pymnt    0
# dtype: int64

# %%
index_missing = df_loans[pd.isnull(df_loans).any(axis = 1)].index
df_loans.iloc[index_missing]
# Out:
#        loan_amnt  funded_amnt        term  int_rate grade  annual_inc  \
# 42449     5000.0       5000.0   36 months      7.43     A         NaN
# 42450     7000.0       7000.0   36 months      7.75     A         NaN
# 42480     6700.0       6700.0   36 months      7.75     A         NaN
# 42533     6500.0       6500.0   36 months      8.38     A         NaN
#
#         issue_d                                        loan_status  dti  \
# 42449  Aug-2007  Does not meet the credit policy. Status:Fully ...  1.0
# 42450  Aug-2007  Does not meet the credit policy. Status:Fully ...  1.0
# 42480  Jul-2007  Does not meet the credit policy. Status:Fully ...  1.0
# 42533  Jun-2007  Does not meet the credit policy. Status:Fully ...  4.0
#
#        revol_bal  total_pymnt
# 42449        0.0      5593.46
# 42450        0.0      7867.53
# 42480        0.0      7530.42
# 42533        0.0      7373.83

# %%
# one hot encode categorical variables for imputation
df_one_hot = pd.get_dummies(df_loans)

# %%
imputed  = SoftImpute().fit_transform(df_one_hot)
# Out:
# [SoftImpute] Max Singular Value of X_init = 96636409.377654
# [SoftImpute] Iter 1: observed MAE=44.772655 rank=4
# [SoftImpute] Iter 2: observed MAE=44.772655 rank=4
# [SoftImpute] Iter 3: observed MAE=44.772655 rank=4
# [SoftImpute] Iter 4: observed MAE=44.772655 rank=4
# [SoftImpute] Iter 5: observed MAE=44.772655 rank=4
# [SoftImpute] Iter 6: observed MAE=44.772655 rank=4
# [SoftImpute] Iter 7: observed MAE=44.772655 rank=4
# [SoftImpute] Iter 8: observed MAE=44.772655 rank=4
# [SoftImpute] Iter 9: observed MAE=44.772654 rank=4
# [SoftImpute] Iter 10: observed MAE=44.772654 rank=4
# [SoftImpute] Iter 11: observed MAE=44.772654 rank=4
# [SoftImpute] Iter 12: observed MAE=44.772654 rank=4
# [SoftImpute] Iter 13: observed MAE=44.772654 rank=4
# [SoftImpute] Iter 14: observed MAE=44.772654 rank=4
# [SoftImpute] Iter 15: observed MAE=44.772654 rank=4
# [SoftImpute] Iter 16: observed MAE=44.772654 rank=4
# [SoftImpute] Iter 17: observed MAE=44.772654 rank=4
# [SoftImpute] Iter 18: observed MAE=44.772654 rank=4
# [SoftImpute] Iter 19: observed MAE=44.772654 rank=4
# [SoftImpute] Iter 20: observed MAE=44.772654 rank=4
# [SoftImpute] Iter 21: observed MAE=44.772654 rank=4
# [SoftImpute] Iter 22: observed MAE=44.772654 rank=4
# [SoftImpute] Iter 23: observed MAE=44.772653 rank=4
# [SoftImpute] Iter 24: observed MAE=44.772653 rank=4
# [SoftImpute] Iter 25: observed MAE=44.772653 rank=4
# [SoftImpute] Iter 26: observed MAE=44.772653 rank=4
# [SoftImpute] Iter 27: observed MAE=44.772653 rank=4
# [SoftImpute] Iter 28: observed MAE=44.772653 rank=4
# [SoftImpute] Iter 29: observed MAE=44.772653 rank=4
# [SoftImpute] Iter 30: observed MAE=44.772653 rank=4
# [SoftImpute] Iter 31: observed MAE=44.772653 rank=4
# [SoftImpute] Iter 32: observed MAE=44.772653 rank=4
# [SoftImpute] Iter 33: observed MAE=44.772653 rank=4
# [SoftImpute] Iter 34: observed MAE=44.772653 rank=4
# [SoftImpute] Iter 35: observed MAE=44.772653 rank=4
# [SoftImpute] Iter 36: observed MAE=44.772653 rank=4
# [SoftImpute] Iter 37: observed MAE=44.772653 rank=4
# [SoftImpute] Iter 38: observed MAE=44.772653 rank=4
# [SoftImpute] Iter 39: observed MAE=44.772653 rank=4
# [SoftImpute] Iter 40: observed MAE=44.772653 rank=4
# [SoftImpute] Iter 41: observed MAE=44.772653 rank=4
# [SoftImpute] Iter 42: observed MAE=44.772653 rank=4
# [SoftImpute] Iter 43: observed MAE=44.772653 rank=4
# [SoftImpute] Iter 44: observed MAE=44.772652 rank=4
# [SoftImpute] Iter 45: observed MAE=44.772652 rank=4
# [SoftImpute] Iter 46: observed MAE=44.772652 rank=4
# [SoftImpute] Iter 47: observed MAE=44.772652 rank=4
# [SoftImpute] Iter 48: observed MAE=44.772652 rank=4
# [SoftImpute] Iter 49: observed MAE=44.772652 rank=4
# [SoftImpute] Iter 50: observed MAE=44.772652 rank=4
# [SoftImpute] Iter 51: observed MAE=44.772652 rank=4
# [SoftImpute] Iter 52: observed MAE=44.772652 rank=4
# [SoftImpute] Iter 53: observed MAE=44.772652 rank=4
# [SoftImpute] Iter 54: observed MAE=44.772652 rank=4
# [SoftImpute] Iter 55: observed MAE=44.772652 rank=4
# [SoftImpute] Iter 56: observed MAE=44.772652 rank=4
# [SoftImpute] Iter 57: observed MAE=44.772652 rank=4
# [SoftImpute] Iter 58: observed MAE=44.772652 rank=4
# [SoftImpute] Iter 59: observed MAE=44.772652 rank=4
# [SoftImpute] Iter 60: observed MAE=44.772652 rank=4
# [SoftImpute] Iter 61: observed MAE=44.772652 rank=4
# [SoftImpute] Iter 62: observed MAE=44.772652 rank=4
# [SoftImpute] Iter 63: observed MAE=44.772652 rank=4
# [SoftImpute] Iter 64: observed MAE=44.772652 rank=4
# [SoftImpute] Iter 65: observed MAE=44.772652 rank=4
# [SoftImpute] Iter 66: observed MAE=44.772652 rank=4
# [SoftImpute] Iter 67: observed MAE=44.772652 rank=4
# [SoftImpute] Iter 68: observed MAE=44.772652 rank=4
# [SoftImpute] Iter 69: observed MAE=44.772652 rank=4
# [SoftImpute] Iter 70: observed MAE=44.772652 rank=4
# [SoftImpute] Iter 71: observed MAE=44.772652 rank=4
# [SoftImpute] Iter 72: observed MAE=44.772652 rank=4
# [SoftImpute] Iter 73: observed MAE=44.772652 rank=4
# [SoftImpute] Iter 74: observed MAE=44.772652 rank=4
# [SoftImpute] Iter 75: observed MAE=44.772652 rank=4
# [SoftImpute] Iter 76: observed MAE=44.772652 rank=4
# [SoftImpute] Iter 77: observed MAE=44.772652 rank=4
# [SoftImpute] Iter 78: observed MAE=44.772652 rank=4
# [SoftImpute] Iter 79: observed MAE=44.772652 rank=4
# [SoftImpute] Iter 80: observed MAE=44.772652 rank=4
# [SoftImpute] Iter 81: observed MAE=44.772652 rank=4
# [SoftImpute] Iter 82: observed MAE=44.772652 rank=4
# [SoftImpute] Iter 83: observed MAE=44.772652 rank=4
# [SoftImpute] Iter 84: observed MAE=44.772652 rank=4
# [SoftImpute] Iter 85: observed MAE=44.772652 rank=4
# [SoftImpute] Iter 86: observed MAE=44.772652 rank=4
# [SoftImpute] Iter 87: observed MAE=44.772652 rank=4
# [SoftImpute] Iter 88: observed MAE=44.772652 rank=4
# [SoftImpute] Iter 89: observed MAE=44.772652 rank=4
# [SoftImpute] Iter 90: observed MAE=44.772652 rank=4
# [SoftImpute] Iter 91: observed MAE=44.772652 rank=4
# [SoftImpute] Iter 92: observed MAE=44.772652 rank=4
# [SoftImpute] Iter 93: observed MAE=44.772652 rank=4
# [SoftImpute] Iter 94: observed MAE=44.772652 rank=4
# [SoftImpute] Iter 95: observed MAE=44.772651 rank=4
# [SoftImpute] Iter 96: observed MAE=44.772651 rank=4
# [SoftImpute] Iter 97: observed MAE=44.772651 rank=4
# [SoftImpute] Iter 98: observed MAE=44.772651 rank=4
# [SoftImpute] Iter 99: observed MAE=44.772651 rank=4
# [SoftImpute] Iter 100: observed MAE=44.772651 rank=4
# [SoftImpute] Stopped after iteration 100 for lambda=1932728.187553

# %%
df_one_hot[df_one_hot.columns] = imputed

# %%
df_loans.annual_inc = df_one_hot.annual_inc

# %%
#review imputed records
df_loans.iloc[index_missing]
# Out:
#        loan_amnt  funded_amnt        term  int_rate grade   annual_inc  \
# 42449     5000.0       5000.0   36 months      7.43     A  5594.992255
# 42450     7000.0       7000.0   36 months      7.75     A  7839.487615
# 42480     6700.0       6700.0   36 months      7.75     A  7503.522304
# 42533     6500.0       6500.0   36 months      8.38     A  7291.625253
#
#         issue_d                                        loan_status  dti  \
# 42449  Aug-2007  Does not meet the credit policy. Status:Fully ...  1.0
# 42450  Aug-2007  Does not meet the credit policy. Status:Fully ...  1.0
# 42480  Jul-2007  Does not meet the credit policy. Status:Fully ...  1.0
# 42533  Jun-2007  Does not meet the credit policy. Status:Fully ...  4.0
#
#        revol_bal  total_pymnt
# 42449        0.0      5593.46
# 42450        0.0      7867.53
# 42480        0.0      7530.42
# 42533        0.0      7373.83

# %% [markdown]
# ## General Data Understanding

# %%
pandas_profiling.ProfileReport(df_loans)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         .center-img {
#             margin-left: auto !important;
#             margin-right: auto !important;
#             display: block;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
#             .pp-anchor{
#
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>11 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>887379 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>0.0% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>74.5 MiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>88.0 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>6 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>4 </td>
#             </tr>
#             <tr>
#                 <th>Boolean</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>1 </td>
#             </tr>
#             <tr>
#                 <th>Unsupported</th>
#                 <td>0 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><a href="#pp_var_annual_inc"><code>annual_inc</code></a> is highly skewed (γ1 = 44.478)  <span class="label label-info">Skewed</span></li><li><a href="#pp_var_dti"><code>dti</code></a> is highly skewed (γ1 = 441.49)  <span class="label label-info">Skewed</span></li><li><a href="#pp_var_funded_amnt"><code>funded_amnt</code></a> is highly correlated with <a href="#pp_var_loan_amnt"><code>loan_amnt</code></a> (ρ = 0.99926) <span class="label label-primary">Rejected</span></li><li><a href="#pp_var_issue_d"><code>issue_d</code></a> has a high cardinality: 103 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_total_pymnt"><code>total_pymnt</code></a> has 17759 / 2.0% zeros <span class="label label-info">Zeros</span></li> </ul>
#     </div>
# </div>
#     <div class="row headerrow highlight">
#         <h1>Variables</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-3 namecol">
#         <p class="h4 pp-anchor" id="pp_var_annual_inc">annual_inc<br/>
#             <small>Numeric</small>
#         </p>
#     </div><div class="col-md-6">
#     <div class="row">
#         <div class="col-sm-6">
#             <table class="stats ">
#                 <tr>
#                     <th>Dis

# %% [markdown]
# # Part 2: Business Analysis
#
# ## 1)

# %%
(df_loans.loan_status.value_counts() / len(df_loans.loan_status)) * 100
# Out:
# Current                                                67.815330
# Fully Paid                                             23.408600
# Charged Off                                             5.099061
# Late (31-120 days)                                      1.306206
# Issued                                                  0.953369
# In Grace Period                                         0.704659
# Late (16-30 days)                                       0.265614
# Does not meet the credit policy. Status:Fully Paid      0.224031
# Default                                                 0.137371
# Does not meet the credit policy. Status:Charged Off     0.085758
# Name: loan_status, dtype: float64

# %% [markdown]
# 23.4% loans were fully paid
#
# Note: an addition 0.22% are marked as "Does not meet the credit policy. Status: Fully Paid" it is not clear if these loans should be included in fully paid.
#
#
#
# ## 2)
# Note: all loans other than those marked as 'Fully Paid' have been mapped to "Defaulted." This mapping includes the small number of loans marked as "Does not meet the credit policy. Status: Fully Paid"

# %%
df_loans.loan_status.values
# Out:
# array(['Fully Paid', 'Charged Off', 'Fully Paid', ..., 'Current',
#        'Current', 'Current'], dtype=object)

# %%
# map loan status
df_loans['loan_status_mapped'] = ['Defaulted' if x != 'Fully Paid' else x for x in df_loans.loan_status.values]

# %%
# split load issues year
df_loans['month'], df_loans['year'] = df_loans['issue_d'].str.split('-').str

# %%
df_loans_bucketed = df_loans.groupby(['year', 'grade', 'loan_status_mapped'], as_index  = False).size()

# %%
df_loans_bucketed = df_loans_bucketed / df_loans_bucketed.groupby(level=[0, 1]).transform("sum")

# %%
df_loans_bucketed.idxmax()
# Out:
# ('2007', 'G', 'Defaulted')

# %% [markdown]
# Loans from 2007 with grade G have the highed Defaulted rate.

# %% [markdown]
# ## 3)

# %%
df_loans['annualized_rate_of_return'] = (df_loans.total_pymnt / df_loans.funded_amnt) ** (1/3) - 1

# %%
pd.DataFrame(df_loans.groupby(['year', 'grade'])['annualized_rate_of_return'].mean().rename("average_annualized_rate_of_return"))
# Out:
#             average_annualized_rate_of_return
# year grade
# 2007 A                               0.027138
#      B                              -0.001888
#      C                              -0.008031
#      D                              -0.014353
#      E                              -0.015099
#      F                              -0.079863
#      G                              -0.044102
# 2008 A                               0.023445
#      B                              -0.000428
#      C                              -0.004508
#      D                              -0.018365
#      E                              -0.003337
#      F                              -0.045138
#      G                              -0.007913
# 2009 A                               0.021337
#      B                               0.014358
#      C                               0.011975
#      D                               0.013982
#      E                              -0.000270
#      F                               0.002615
#      G                               0.002985
# 2010 A                               0.022177
#      B                               0.022080
#      C                               0.022898
#      D                               0.016974
#      E                               0.023725
#      F                               0.024565
#      G                               0.020042
# 2011 A                               0.015049
#      B                               0.020336
# ...                                       ...
#      F                               0.014506
#      G                               0.005108
# 2012 A                               0.015106
#      B                               0.019565
#      C                               0.015836
#      D                               0.012208
#      E                              -0.000143
#      F                              -0.004124
#      G                              -0.015510
# 2013 A                              -0.015742
#      B                              -0.011406
#      C                              -0.028646
#      D                              -0.024081
#      E                              -0.041085
#      F                              -0.053547
#      G                              -0.055009
# 2014 A                              -0.142876
#      B                              -0.137111
#      C                              -0.150848
#      D                              -0.159592
#      E                              -0.165378
#      F                              -0.153738
#      G                              -0.167700
# 2015 A                              -0.462427
#      B                              -0.476787
#      C                              -0.467296
#      D                              -0.454088
#      E                              -0.457781
#      F                              -0.449636
#      G                              -0.427172
#
# [63 rows x 1 columns]
